# %% [markdown]
# ## Visualisation & Accessibility
#
# Welcome to the **Visualisation & Accessibility Module** where you'll learn about how to display data nicely.
#
# #### Lessons
# | Type    | Lesson                                                                |
# |---------|-----------------------------------------------------------------------|
# | Lecture | <a href="$./6.1 Intro" target="_self">Introduction</a>                |
# | Lab     | <a href="$./6.2 Visualisation" target="_self">Visualisation</a>       |
# | Lecture | <a href="$./6.3 Accessibility" target="_self">Accessibility</a>       |
# | Lab     | <a href="$./6.4 Visualisation II" target="_self">Visualisation II</a> |

# %% [markdown]
# &copy; 2024 Thoughtworks. All rights reserved.<br/>
