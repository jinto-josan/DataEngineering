# %% [markdown]
# ## Streaming
#
# Welcome to the **Streaming Module**. You will be learning about the Spark Structured streaming module here.
#
# #### Lessons
# | Type    | Lesson                                                                |
# |---------|-----------------------------------------------------------------------|
# | Lecture | <a href="$./7.01 Intro to Streaming" target="_self">7.01 Intro to Streaming</a>|
# | Lecture | <a href="$./7.02 Spark Structured Streaming" target="_self">7.02 Spark Structured Streaming</a>|
# | Lab | <a href="$./7.03 Stateful vs Stateless Streaming" target="_self">7.03 Stateful vs Stateless Streaming</a>|
# | Lab | <a href="$./7.04 Checkpointing" target="_self">7.04 Checkpointing</a>|
# | Lab | <a href="$./7.05 Handling Late Data" target="_self">7.05 Handling Late Data</a>|
# | Lab | <a href="$./7.06 Handling Late Data - Tumbling Windows with Watermarks" target="_self">7.06 Handling Late Data - Tumbling Windows with Watermarks</a>|
# | Lab | <a href="$./7.07 Handling Late Data - Sliding Windows" target="_self">7.07 Handling Late Data - Sliding Windows</a>|
# | Lab | <a href="$./7.08 Handling Late Data - Sliding Windows with Watermarks" target="_self">7.08 Handling Late Data - Sliding Windows with Watermarks</a>|
# | Lecture | <a href="$./7.09 Stateful Streaming in a Nutshell" target="_self">7.09 Stateful Streaming in a Nutshell</a>|
# | Lab | <a href="$./7.10 Exercise Streaming" target="_self">7.10 Exercise Streaming</a>|

# %% [markdown]
# | Next Topic |
# | --- |
# <a href="$./7.01 Intro to Streaming" target="_self">7.01 Intro to Streaming</a>

# %% [markdown]
# &copy; 2024 Thoughtworks. All rights reserved.<br/>
