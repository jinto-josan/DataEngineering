# %% [markdown]
# ## Introduction
#
# Welcome to the **Data Architecture Module** where you'll learn about commonly used architectures in a data engineering project, popular data formats used, and you'll start working with **[Apache Spark™](https://spark.apache.org/)**.
#
# #### Lessons
# | Type    | Lesson                                                                                                      |
# |---------|-------------------------------------------------------------------------------------------------------------|
# | Lecture | <a href="$./2.1 Data Architecture" target="_self">Data Architecture</a>                                     |
# | Lecture | <a href="$./2.2 Data Formats" target="_self">Data Formats</a>                                               |
# | Lab     | <a href="$./2.3 Apache Spark Primer" target="_self">Apache Spark Primer</a>                                 |
# | Lab     | <a href="$./2.4 Gentle Introduction to Apache Spark" target="_self">Gentle Introduction to Apache Spark</a> |
#
# #### Prerequisites
# * Be familiar and aware of the data engineering concepts and terminology
# * Beginner experience with SQL and Python

# %% [markdown]
# | Next Topic |
# | --- |
# | <a href="$./2.1 Data Architecture" target="_self">Data Architecture</a> |

# %% [markdown]
# &copy; 2024 Thoughtworks. All rights reserved.<br/>
