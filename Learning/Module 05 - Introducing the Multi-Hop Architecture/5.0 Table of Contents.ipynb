# %% [markdown]
# ## Introduction
#
# Welcome to the **Multi-Hop Architecture Module**, in this module you will have the opportunity to apply the Multi-Hop or **[Medallion Architecture](https://www.databricks.com/glossary/medallion-architecture)** for the EV domain that we worked in previous modules.
#
# #### Lessons
# | Type    | Lesson                                                                                                |
# |---------|-------------------------------------------------------------------------------------------------------|
# | Lecture | <a href="$./5.1 Introduction" target="_self">Introduction</a> |
# | Lecture | <a href="$./5.2 Multi-Hop Architecture - Applied" target="_self">Multi-Hop Architecture - Applied</a> |
# | Lab     | <a href="$./5.3 Exercise - Bronze" target="_self">Exercise - Bronze</a>                               |
# | Lab     | <a href="$./5.4 Exercise - Silver" target="_self">Exercise - Silver</a>                               |
# | Lab     | <a href="$./5.5 Exercise - Gold" target="_self">Exercise - Gold</a>                                   |
# | Lecture | <a href="$./5.6 Data-Quality" target="_self">Data Quality</a>                                         |
#
#
# #### Prerequisites
# We'll apply what we learned in the <a href="$../Module 02 - Data Architecture/2.5 Data Platforms" target="_self">**Data Platform**</a> lesson from the Architecture module, so if you need it feel free to review it and recap this knowlege before jumping to the lessons of this module.

# %% [markdown]
# | Next Topic |
# | --- |
# | <a href="$./5.1 Introduction" target="_self">Introduction</a> |

# %% [markdown]
# &copy; 2024 Thoughtworks. All rights reserved.<br/>
