# %% [markdown]
# ## Introduction
#
# Welcome to the **Data security and privacy Module** where you'll learn about good practices in data security and privacy in large-scale data workflows.
#
#
# #### Lessons
# | Type    | Lesson                                                                                                                |
# |---------|-----------------------------------------------------------------------------------------------------------------------|
# | Lecture | <a href="$./8.1 Intro" target="_self">Introduction</a>                                                                |
# | Lab     | <a href="$./8.2 Security and Privacy in Data Engineering" target="_self">Security and Privacy in Data Engineering</a> |
# | Lecture | <a href="$./8.3 Socially-Responsible-ML" target="_self">Socially-Responsible-ML</a>                                   |
#
# **Learning Objectives**
#
# By the end of this chapter, you should be able to do the following:
# - Understand the need for privacy in data workflows.
# - Learn to indentify sensitive data types.
# - Implement privacy enhancements.
# - Learn about privacy by design.

# %% [markdown]
# &copy; 2024 Thoughtworks. All rights reserved.<br/>
