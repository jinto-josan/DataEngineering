# %% [markdown]
# ## Introduction
#
# Welcome to the **Data Ingestion and Basic Transformations Module** where you'll learn about data ingestion and data transformation in Apache Spark.
# What we do with and to our data should always serve a greater purpose, so before we start working with our data,
# we'll first have a look at some more advanced concepts about Data Platforms and Data Mesh to get an idea about the big picture.
#
# #### Lessons
# | Type    | Lesson                                                                                                          |
# |---------|-----------------------------------------------------------------------------------------------------------------|
# | Lecture | <a href="$./3.1 Data Platforms " target="_self">Data Platforms</a>                                              |
# | Lecture | <a href="$./3.2 Data Mesh" target="_self">Data Mesh</a>                                                         |
# | Lecture | <a href="$./3.3 Practice Domain Introduction" target="_self">Practice Domain Introduction</a>                   |
# | Lab     | <a href="$./3.4 Last Connection Time of Charge Points" target="_self">Last Connection Time of Charge Points</a> |
#
# #### Prerequisites
# * Be familiar and aware of the data engineering concepts and terminology
# * Beginner experience with Python

# %% [markdown]
# | Next Topic                                                        |
# |-------------------------------------------------------------------|
# | <a href="$./3.1 Data Platforms" target="_self">Data Platforms</a> |

# %% [markdown]
# &copy; 2024 Thoughtworks. All rights reserved.<br/>
