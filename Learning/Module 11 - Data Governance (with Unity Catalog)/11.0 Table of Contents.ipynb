# %% [markdown]
# ## Data Governance (with Unity Catalog)
#
# Welcome to the **Data Governance Module**.
#
#
# #### Lessons
# | Type    | Lesson                                                                                             |
# |---------|----------------------------------------------------------------------------------------------------|
# | Lecture | <a href="$./11.1 Introduction" target="_self">Introduction</a>                                     |
# | Lab     | <a href="$./11.2 Create and Govern Data with UC" target="_self">Create and Govern Data with UC</a> |
#
#
# **Learning Objectives**
#
# By the end of this chapter, you should be able to:
# - understand the need for privacy in data workflows
# - identify sensitive data types
# - implement privacy enhancements
# - learn about privacy by design

# %% [markdown]
# &copy; 2024 Thoughtworks. All rights reserved.<br/>
