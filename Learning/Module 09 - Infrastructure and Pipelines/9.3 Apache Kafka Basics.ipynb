# %% [markdown]
# ## Basics of Apache Kafka
#
# Here is a list of very useful videos on some basic of Apache Kafka. Please get in touch with your trainers if you would like to do some hands in these topics (like kakfa set up on local machine, multi node set up, kafka partitions in action) once you are done with the videos
#
# * [Apache Kafka in 5 mins](https://youtu.be/PzPXRmVHMxI?si=7YAoCXw4cOLmrU3K)
# * [Kafka Deep Dive](https://youtu.be/qu96DFXtbG4?si=0XHCxgODpiXJLanG)
# * [Kafka Topics](https://youtu.be/qu96DFXtbG4?si=0XHCxgODpiXJLanG)
# * [Topics Demo](https://youtu.be/oI7VAS9KSS4?si=3CBJs9lRDLtsybr1)
# * [Partitions](https://youtu.be/y9BStKvVzSs?si=cPiPmi8Lo3Lv5WTt)
# * [Partitions Demo](https://youtu.be/GvdlpbQr6jo?si=rccBQJCRaBquVU6v)
# * [Putting it all together](https://youtu.be/_q1IjK5jjyU?si=Dt_UkClxsEpOxcb7)

# %% [markdown]
# | Next Topic                                                                                                            |
# |-----------------------------------------------------------------------------------------------------------------------|
# | <a href="$./9.4 Exercise Apache Kafka" target="_self">9.4 Exercise Apache Kafka</a> |
#
# &copy; 2024 Thoughtworks. All rights reserved.<br/>
