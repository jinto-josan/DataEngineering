# %% [markdown]
# ## Azure
#
# Like AWS Kinesis, Azure has Event hubs. You can understand more about it in [this article](https://learn.microsoft.com/en-us/azure/event-hubs/azure-event-hubs-kafka-overview) and [video](https://youtu.be/Dc3P27BsK3E?si=AThH4YMESMEKY9Fu).
#
# However, unlike Amazon Kinesis, Azure Event Hubs endpoints are fully-compatible with Kafka’s Producer and Consumer APIs

# %% [markdown]
# So as mentioned in the introduction notebook, here is what you need to do now :
#
# 1. Try to come up with a `theoretical` implementation in technologies you learn in the previous sections, similar to what you have learnt in Databricks in this course till this point.
# 3. Be ready with your presentations in the next Q&A session with your trainers

# %% [markdown]
# | Next Topic                                                                                                            |
# |-----------------------------------------------------------------------------------------------------------------------|
# | <a href="$../Module 10 - Exploring Databricks/Exploring Databricks Partner Portal" target="_self">Exploring Databricks Partner Portal</a> |
#
# &copy; 2024 Thoughtworks. All rights reserved.<br/>
