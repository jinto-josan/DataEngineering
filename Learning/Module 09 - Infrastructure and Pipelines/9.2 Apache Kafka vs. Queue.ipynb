# %% [markdown]
# ## Kafka vs. Queue Comparison
#
# Let us start with understanding some vital differences between Apache Kakfa and Queue (Well, RabbitMQ, to be more specfic) at this YouTube [link](https://youtu.be/w8xWTIFU4C8?si=r1qX8DRx_LQMhhbp).
#
# Once done, and to further solidify the understanding, have a look at [this](https://betterprogramming.pub/rabbitmq-vs-kafka-1ef22a041793) article in a similar kind of comparison.

# %% [markdown]
# | Next Topic                                                                                                            |
# |-----------------------------------------------------------------------------------------------------------------------|
# | <a href="$./9.3 Apache Kafka Basics" target="_self">9.3 Apache Kafka Basics</a> |
#
# &copy; 2024 Thoughtworks. All rights reserved.<br/>
