# %% [markdown]
# ## Final Project
#
# Welcome to the **final project** notebook. This is your chance to apply all the knowledge you have gained in the previous modules. All the details for this assginment are documented in the next notebook. Wish you the best !
#
#
# #### Lessons
# | Type    | Lesson                                                            |
# |---------|-------------------------------------------------------------------|
# | Lecture | <a href="$./12.1 Final Project Assignment Details" target="_self">Final Project Assignment Details</a>  |

# %% [markdown]
# &copy; 2024 Thoughtworks. All rights reserved.<br/>
